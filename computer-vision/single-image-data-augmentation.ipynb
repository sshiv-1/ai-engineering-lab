# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import RandomZoom,RandomFlip,RandomRotation,RandomBrightness,RandomContrast,Rescaling

# %%
img = load_img(
    "C:/Coding/ML_DL/Data-Aurgumentation/train/cat.jpg",
    target_size=(225, 225)
)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %% [markdown]
# # Data Aurgumentation Pipeline

# %%
from tensorflow.keras.utils import img_to_array
img_arr=img_to_array(img)
print(img_arr.shape)
img_arr=tf.expand_dims(img_arr,axis=0)
img_arr.shape
# Out:
# (225, 225, 3)
# TensorShape([1, 225, 225, 3])

# %%
data_augmentation = Sequential([
    RandomFlip("horizontal"),
    RandomRotation(0.1),
    RandomZoom(0.2),
    RandomBrightness(0.2),
    RandomContrast(0.1),
])

augmented_img = data_augmentation(img_arr, training=True)
augmented_img.shape
# Out:
# TensorShape([1, 225, 225, 3])

# %%
augmented_img = augmented_img / 255.0

# %%
for i in range(5):
    aug = data_augmentation(img_arr, training=True)

# %%
plt.figure(figsize=(10, 4))

for i in range(10):
    aug = data_augmentation(img_arr, training=True)

    plt.subplot(2, 5, i + 1)

    # Remove batch dimension
    img = tf.squeeze(aug, axis=0)

    # Convert to uint8 for display
    img = tf.cast(img, tf.uint8)

    plt.imshow(img)
    plt.axis("off")

plt.show()
